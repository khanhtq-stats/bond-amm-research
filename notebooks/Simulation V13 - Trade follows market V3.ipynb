# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns 
import numpy as np

# %%
import yaml

# %%
import os 

os.chdir('E://bond-dex/bond-amm-simulation/')

# %%
from simulation.__NaiveTradeSimulator import NaiveTradeSimulator

# %%
from scripts.generate_stats_v1 import plot_stats

# %%
# %load_ext autoreload

# %% [markdown]
# ## Simulation for Yield

# %%
# %autoreload 2

from simulation.__NaiveTradeSimulator import NaiveTradeSimulator

# %%
# %%writefile config/yield_v1.yml
#
# # time unit: minute
#
# config:
#   simulation:
#     simulation_length: 525500
#     begin_trade_time: 0
#     maturity: 5256000 #525600
#     initial_cash: 0.5
#     initial_bond: 0.8243606353500641
#
#   fee:
#     rate: 0.
#
#   pricing_config:
#       pricing_method: 'yield-v1'
#       params:
#
#   other-protocol:
#     type: 'CIR'
#     params:
#         a: 5
#         b: 0.06
#         sigma: 0.2
#         r0: 0.05
#
#   arbitrageur:
#     strategy: 'naive-arbitrageur'
#     params:
#       estimate_func: 'yield'
#
#
#   tracking:
#     dir: 'data/tracking-v13/yield_v1'
# Out:
# Overwriting config/yield_v1.yml

# %%
with open('config/yield_v1.yml') as file:
    metadata = yaml.safe_load(file)

simulator = NaiveTradeSimulator(metadata['config'])
simulator.run()
# Out:
# Initialized simulation!
#
# ------------- Begin running simulation -------------
# 100%|████████████████████████████████████████████████████████████████████████| 525500/525500 [01:14<00:00, 7034.43it/s]
# Total_burn: 0
#
# Saving tracking data to data/tracking-v13/yield_v1
#
# ------------------ Done simulation ------------------

# %%
from scripts.generate_stats_v1 import plot_stats

fig = plt.figure(figsize=(10, 8))

plot_stats('data/tracking-v13/yield_v1', 'ALL_INFORMATION.json', fig_size=(12, 9))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# %autoreload 2

from scripts.generate_stats_v2 import plot_stats

fig = plt.figure(figsize=(10, 16))

plot_stats('data/tracking-v13/yield_v1', 'ALL_INFORMATION.json', fig_size=(18, 9))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Proposed logit

# %% [markdown]
# $p = \frac{X_0}{X_0 + y_0}$
#
# $r = \kappa logit(p) + r^{\star}$

# %% [markdown]
# $\alpha = \frac{1}{1 + \tau\kappa}$
#
# $B^\star = e^{-r^\star \tau}$
#
# $X_0 = x_0B^\star$
#
# $X_{1}^{\alpha} + y_{1}^{\alpha} = X_{0}^{\alpha} + y_{0}^{\alpha}$
#
# $x_1 = X_{1}B^\star$

# %%
_user_defined_func_path = "scripts/price_functions/price_v1.py"

# %%
# %%writefile {_user_defined_func_path}
#
# import numpy as np
# from scipy.special import logit
#
#
# def calculate_price(x, y, dx, dy, time_to_maturity, maturity_length, r_star, kappa) -> float:
#     tau = time_to_maturity
#
#     alpha = 1 / (1 + tau * kappa)
#     Br = np.exp(-r_star * tau)
#
#     C = (x * Br) ** alpha + y ** alpha
#
#     if dx != 0:
#         new_x = x + dx
#         new_y = (C - (Br * new_x) ** alpha) ** (1 / alpha)
#         dy = new_y - y
#     elif dy != 0:
#         new_y = y + dy
#         new_x = (C - new_y ** alpha) ** (1 / alpha) / Br
#         dx = new_x - x
#
#     if abs((x * Br) ** alpha + y ** alpha - ((x + dx) * Br) ** alpha - (y + dy) ** alpha) > 0.00001:
#         raise Exception('Something wrong with ODE!')
#
#     r0 = r_star * alpha + kappa * alpha * np.log(x / y)
#     if abs(logit(x * np.exp(-r0 * tau) / (x * np.exp(-r0 * tau) + y)) * kappa + r_star - r0) > 0.00001:
#         raise Exception('R0 not match!')
#
#     if dx == 0 and dy == 0:
#         dy = -np.exp(-tau * r0)
#         dx = 1
#
#     price = abs(dy / dx)
#
#     return price
# Out:
# Overwriting scripts/price_functions/price_v1.py

# %%
# %%writefile config/user_defined_v1.yml
#
#
# version_name: 'v1'
#
# config:
#   simulation:
#     simulation_length: 525500
#     begin_trade_time: 0
#     maturity: 5256000
#     initial_cash: 0.5
#     initial_bond: 0.8243606353500641
#     bond_burning: 1
#
#   fee:
#     rate: .000
#
#   pricing_config:
#       pricing_method: 'user-defined'
#       params:
#         price_function: 'scripts/price_functions/price_v1.py'
#         kappa: 0.02
#         r_star: 0.05
#
#   other-protocol:
#     type: 'CIR'
#     params:
#         a: 5
#         b: 0.06
#         sigma: 0.2
#         r0: 0.05
#
#   arbitrageur:
#     strategy: 'naive-arbitrageur'
#     params:
#       estimate_func: 'polybond'
#       kappa: 0.02
#       r_star: 0.05
#
# #   trader:
# #     trade_data: 'sources/input/actor_trade/single_trade2.csv'
#
#   tracking:
#     dir: 'data/tracking-v13/v1.1'
# Out:
# Overwriting config/user_defined_v1.yml

# %%
# %autoreload 2

from simulation.__NaiveTradeSimulator import NaiveTradeSimulator

# %%
with open('config/user_defined_v1.yml') as file:
    metadata = yaml.safe_load(file)

simulator = NaiveTradeSimulator(metadata['config'])
simulator.run()
# Out:
# Initialized simulation!
#
# ------------- Begin running simulation -------------
#  23%|████████████████▎                                                       | 118981/525500 [00:12<01:15, 5367.71it/s]E:\bond-dex\bond-amm-simulation\actors\strategies\__NaiveArbitrager.py:71: RuntimeWarning: invalid value encountered in scalar power
#   price = (y - (K * x ** alpha + y ** alpha - K * (x + dx) ** alpha) ** (1 / alpha)) / dx
# 100%|████████████████████████████████████████████████████████████████████████| 525500/525500 [01:53<00:00, 4643.96it/s]
# Total_burn: -0.22973056183306045
#
# Saving tracking data to data/tracking-v13/v1.1
#
# ------------------ Done simulation ------------------

# %%
# %autoreload 2

from scripts.generate_stats_v1 import plot_stats

# %%
# %autoreload 2

from scripts.generate_stats_v2 import plot_stats

fig = plt.figure(figsize=(10, 16))

plot_stats('data/tracking-v13/v1.1', 'ALL_INFORMATION.json', fig_size=(18, 9))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Notional Finance

# %%
# %%writefile config/logit_notional_v3.yml
#
# version_name: 'linear-notional-v1'
#
# # time unit: minute
#
# config:
#   simulation:
#     simulation_length: 525500
#     begin_trade_time: 0
#     maturity: 5256000
#     initial_cash: 0.5
#     initial_bond: 0.5
#
#   fee:
#     rate: 0.
#
#   pricing_config:
#       pricing_method: 'logit-notional-v3'
#       params:
#         kappa: 0.02
#         r_star: 0.05
#
#   other-protocol:
#     type: 'CIR'
#     params:
#         a: 5
#         b: 0.06
#         sigma: 0.2
#         r0: 0.05
#
#   arbitrageur:
#     strategy: 'naive-arbitrageur'
#     params:
#       estimate_func: 'notional'
#       kappa: 0.02
#       r_star: 0.05
#
#   tracking:
#     dir: 'data/tracking-v13/notional-v3'
# Out:
# Overwriting config/logit_notional_v3.yml

# %%
# %autoreload 2

from simulation.__NaiveTradeSimulator import NaiveTradeSimulator

# %%
with open('config/logit_notional_v3.yml') as file:
    metadata = yaml.safe_load(file)

simulator = NaiveTradeSimulator(metadata['config'])
simulator.run()
# Out:
# Initialized simulation!
#
# ------------- Begin running simulation -------------
# 100%|████████████████████████████████████████████████████████████████████████| 525500/525500 [01:09<00:00, 7594.60it/s]
# Total_burn: 0
#
# Saving tracking data to data/tracking-v13/notional-v3
#
# ------------------ Done simulation ------------------

# %%
# %autoreload 2

from scripts.generate_stats_v2 import plot_stats

fig = plt.figure(figsize=(10, 16))

plot_stats('data/tracking-v13/notional-v3/', 'ALL_INFORMATION.json', fig_size=(18, 9))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import json


def read_data(folder_dir, file_path):
    file_path = os.path.join(folder_dir, file_path)

    with open(file_path, 'r') as file:
        data = json.load(file)

    _df = pd.DataFrame(data['value'])
    _df['timestamp'] = data['timestamp']
    _df['pool_address'] = data['pool_address']

    return _df

# %%
df = read_data('data/tracking/notional-v2/', 'ALL_INFORMATION.json')

# %%
df
# Out:
#           cash      bond  net_bond  time_to_maturity  interest_rate  \
# 0     0.500000  0.525636 -0.000000           5255999       0.051000
# 1     0.532172  0.472943 -0.052688           5255899       0.047640
# 2     0.547187  0.448952 -0.076675           5255799       0.046042
# 3     0.564292  0.422089 -0.103533           5255699       0.044193
# 4     0.565633  0.420002 -0.105618           5255599       0.044046
# ...        ...       ...       ...               ...            ...
# 5250  0.143949  1.162131  0.676496           4730999       0.091771
# 5251  0.154063  1.139191  0.653574           4730899       0.090014
# 5252  0.153819  1.139720  0.654123           4730799       0.090055
# 5253  0.178060  1.086142  0.600563           4730699       0.086165
# 5254  0.168438  1.107159  0.621597           4730599       0.087660
#
#       accumulated_fee  last_price  timestamp  \
# 0                 0.0         NaN          1
# 1                 0.0    0.620298        101
# 2                 0.0    0.630418        201
# 3                 0.0    0.642014        301
# 4                 0.0    0.643339        401
# ...               ...         ...        ...
# 5250              0.0    0.438672     525001
# 5251              0.0    0.445449     525101
# 5252              0.0    0.445014     525201
# 5253              0.0    0.461227     525301
# 5254              0.0    0.454127     525401
#
#                                     pool_address
# 0     0xlbvpccssxnilxacvbfxrrjxogggzxo1699115315
# 1     0xlbvpccssxnilxacvbfxrrjxogggzxo1699115315
# 2     0xlbvpccssxnilxacvbfxrrjxogggzxo1699115315
# 3     0xlbvpccssxnilxacvbfxrrjxogggzxo1699115315
# 4     0xlbvpccssxnilxacvbfxrrjxogggzxo1699115315
# ...                                          ...
# 5250  0xlbvpccssxnilxacvbfxrrjxogggzxo1699115315
# 5251  0xlbvpccssxnilxacvbfxrrjxogggzxo1699115315
# 5252  0xlbvpccssxnilxacvbfxrrjxogggzxo1699115315
# 5253  0xlbvpccssxnilxacvbfxrrjxogggzxo1699115315
# 5254  0xlbvpccssxnilxacvbfxrrjxogggzxo1699115315
#
# [5255 rows x 9 columns]
