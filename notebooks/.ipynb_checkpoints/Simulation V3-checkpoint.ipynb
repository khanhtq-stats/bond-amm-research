# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns 
import numpy as np

# %%
import yaml

# %%
import os 

os.chdir('E://bond-dex/bond-amm-simulation/')

# %%
from simulation.__NaiveTradeSimulator import NaiveTradeSimulator

# %%
from scripts.generate_stats_v1 import plot_stats

# %% [markdown]
# ## Simulation for Yield

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

from simulation.__NaiveTradeSimulator import NaiveTradeSimulator

# %%
# %%writefile config/yield_v1.yml
#
# # time unit: minute
#
# config:
#   simulation:
#     simulation_length: 525500
#     begin_trade_time: 0
#     maturity: 5256000 #525600
#     initial_cash: 0.5
#     initial_bond: 0.5256355481880121
#     bond_burning: 1
#
#   fee:
#     rate: 0.
#
#   trader:
#     trade_data: 'sources/input/actor_trade/single_trade.csv'
#
#   pricing_config:
#       pricing_method: 'yield-v1'
#       params:
#
#   tracking:
#     dir: 'data/tracking/yield_v1'
# Out:
# Overwriting config/yield_v1.yml

# %%
with open('config/yield_v1.yml') as file:
    metadata = yaml.safe_load(file)

simulator = NaiveTradeSimulator(metadata['config'])
simulator.run()
# Out:
# Initialized simulation!
#
# ------------- Begin running simulation -------------
# 100%|████████████████████████████████████████████████████████████████████████| 525500/525500 [01:04<00:00, 8123.99it/s]
# Total_burn: 0.015681845409314686
#
# Saving tracking data to data/tracking/yield_v1
#
# ------------------ Done simulation ------------------

# %%
from scripts.generate_stats_v1 import plot_stats

fig = plt.figure(figsize=(10, 8))

plot_stats('data/tracking/yield_v1', 'ALL_INFORMATION.json', fig_size=(12, 9))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Notional V2

# %%
# %%writefile config/logit_notional_v1.yml
#
#
# version_name: 'v1'
#
# config:
#   simulation:
#     simulation_length: 525500
#     begin_trade_time: 0
#     maturity: 5256000 #525600
#     initial_cash: 0.5
#     initial_bond: 0.5256355481880121
#     bond_burning: 0
#
#   fee:
#     rate: .000
#
#   pricing_config:
#       pricing_method: 'logit-notional-v1'
#       params:
#         rate_scalar: 50
#         rate_anchor: 1.05
# #         kappa: 0.02
# #         r_star: 0.05
#
#   trader:
#     trade_data: 'sources/input/actor_trade/single_trade.csv'
#
#   tracking:
#     dir: 'data/tracking/notional-v1'
# Out:
# Overwriting config/logit_notional_v1.yml

# %%
# %load_ext autoreload

# %%
# %autoreload 2

from simulation.__NaiveTradeSimulator import NaiveTradeSimulator

# %%
with open('config/logit_notional_v1.yml') as file:
    metadata = yaml.safe_load(file)

simulator = NaiveTradeSimulator(metadata['config'])
simulator.run()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 4
#       1 with open('config/logit_notional_v1.yml') as file:
#       2     metadata = yaml.safe_load(file)
# ----> 4 simulator = NaiveTradeSimulator(metadata['config'])
#       5 simulator.run()
#
# File E:\bond-dex\bond-amm-simulation\simulation\__NaiveTradeSimulator.py:39, in NaiveTradeSimulator.__init__(self, config)
#      36 else:
#      37     self.bond_burning = False
# ---> 39 self.protocol = BondIssuingProtocolV1(config)
#      41 self._initialize()
#      43 self._pool_address = self.protocol.view_all_pools()['pool_info'][0]['pool_address']
#
# File E:\bond-dex\bond-amm-simulation\protocols\fixed_rate\bond_issuing\__BondIssuingProtocolV1.py:30, in BondIssuingProtocolV1.__init__(self, config)
#      28 begin_time = self._config['simulation']['begin_trade_time']
#      29 maturity = self._config['simulation']['maturity']
# ---> 30 self._initialize(begin_time, maturity)
#      32 self._liquidity_initialization = False
#
# File E:\bond-dex\bond-amm-simulation\protocols\fixed_rate\bond_issuing\__BondIssuingProtocolV1.py:60, in BondIssuingProtocolV1._initialize(self, from_date, maturity)
#      57 self._information_center = InformationCenterV1()
#      58 self._information_center.register_pool_center(self._pool_center)
# ---> 60 self._logic_control = LogicControlV1(config=self._config)
#      62 self._business_control = BusinessControlV1()
#      63 self._business_control.register_execution_center(self._execution_center)
#
# File E:\bond-dex\bond-amm-simulation\protocols\core\control_center\logic_control\__LogicControlV1.py:16, in LogicControlV1.__init__(self, config)
#      13 interest_function_config = config['pricing_config']
#      15 self._bond_lp_control = BondLPControl()
# ---> 16 self._bond_lp_control.load_config(interest_function_config)
#
# File E:\bond-dex\bond-amm-simulation\protocols\core\control_center\logic_control\__BondLPControl.py:60, in BondLPControl.load_config(self, config)
#      57 elif pricing_method == 'user-defined':
#      58     self.price_calculator = UserDefinedPriceCalculatorV1()
# ---> 60 self.price_calculator.load_config(config['params'])
#
# AttributeError: 'NoneType' object has no attribute 'load_config'

# %%
# %autoreload 2

from scripts.generate_stats_v1 import plot_stats

# %%
fig = plt.figure(figsize=(10, 8))

plot_stats('data/tracking/notional-v1', 'ALL_INFORMATION.json', fig_size=(12, 9))

# %% [markdown]
# ## Proposed logit

# %% [markdown]
# $p = \frac{X_0}{X_0 + y_0}$
#
# $r = \kappa logit(p) + r^{\star}$

# %% [markdown]
# $C_1 = y_0[e^{\kappa^{-1}(r_0 - r^\star)} + 1]^{\tau\kappa + 1}$
#
# $\alpha = \frac{1}{1 + \tau\kappa}$
#
# $K = e^{-\tau r^{\star} \alpha}$
#
# $C_2 = C_1^{\alpha}$
#
# $Kx^\alpha + y^\alpha = C_2$

# %% [markdown]
# At time t, suppose the state of pool is $(x_0, y_0, r_0)$, and there is a trade dy to the pool.
#
# -> $Kx_{0}^{\alpha} + y_0^{\alpha} = C_2$
#
# -> $r_{0} = r^{\star} - \kappa \bigr[ln(K) + \alpha ln(\frac{x_0}{y_0})\bigr]$
#
# -> $K(x + dx)^{\alpha} + (y+dy)^{\alpha} = K x_0^{\alpha} + y_0^{\alpha}$

# %%
_user_defined_func_path = "scripts/price_functions/price_v1.py"

# %%
# %%writefile {_user_defined_func_path}
#
# import numpy as np
# from scipy.special import logit
#
#
# def calculate_price(x, y, dx, dy, time_to_maturity, maturity_length, r_star, kappa) -> float:
#     tau = time_to_maturity
#
#     alpha = 1 / (1 + tau * kappa)
#     Br = np.exp(-r_star * tau)
#
#     C = (x * Br) ** alpha + y ** alpha
#
#     if dx != 0:
#         new_x = x + dx
#         new_y = (C - (Br * new_x) ** alpha) ** (1 / alpha)
#         dy = new_y - y
#     elif dy != 0:
#         new_y = y + dy
#         new_x = (C - new_y ** alpha) ** (1 / alpha) / Br
#         dx = new_x - x
#
#     if abs((x * Br) ** alpha + y ** alpha - ((x + dx) * Br) ** alpha - (y + dy) ** alpha) > 0.00001:
#         raise Exception('Something wrong with ODE!')
#
#     r0 = r_star * alpha + kappa * alpha * np.log(x / y)
#     if abs(logit(x * np.exp(-r0 * tau) / (x * np.exp(-r0 * tau) + y)) * kappa + r_star - r0) > 0.00001:
#         raise Exception('R0 not match!')
#
#     if dx == 0 and dy == 0:
#         dy = -np.exp(-tau * r0)
#         dx = 1
#
#     price = abs(dy / dx)
#
#     return price
# Out:
# Overwriting scripts/price_functions/price_v1.py

# %%
# %%writefile config/user_defined_v1.yml
#
#
# version_name: 'v1'
#
# config:
#   simulation:
#     simulation_length: 525500
#     begin_trade_time: 0
#     maturity: 5256000 #525600
#     initial_cash: 0.5
#     initial_bond: 0.5256355481880121
#     bond_burning: 1
#
#   fee:
#     rate: .000
#
#   pricing_config:
#       pricing_method: 'user-defined'
#       params:
#         price_function: 'scripts/price_functions/price_v1.py'
#         kappa: 0.02
#         r_star: 0.05
#
#   trader:
#     trade_data: 'sources/input/actor_trade/single_trade.csv'
#
#   tracking:
#     dir: 'data/tracking/v1.1'
# Out:
# Overwriting config/user_defined_v1.yml

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

from simulation.__NaiveTradeSimulator import NaiveTradeSimulator

# %%
with open('config/user_defined_v1.yml') as file:
    metadata = yaml.safe_load(file)

simulator = NaiveTradeSimulator(metadata['config'])
simulator.run()
# Out:
# Initialized simulation!
#
# ------------- Begin running simulation -------------
#   7%|█████                                                                    | 36440/525500 [00:04<00:57, 8462.24it/s]scripts/price_functions/price_v1.py:20: RuntimeWarning: invalid value encountered in scalar power
#   new_x = (C - new_y ** alpha) ** (1 / alpha) / Br
# 100%|████████████████████████████████████████████████████████████████████████| 525500/525500 [01:27<00:00, 5976.79it/s]
# Total_burn: -0.03142316189197385
#
# Saving tracking data to data/tracking/v1.1
#
# ------------------ Done simulation ------------------

# %%
# %autoreload 2

from scripts.generate_stats_v1 import plot_stats

# %%
fig = plt.figure(figsize=(10, 8))

plot_stats('data/tracking/v1.1', 'ALL_INFORMATION.json', fig_size=(12, 9))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def lob_density(x, y, tau, kappa, r_star, u):
    
    K = np.exp(-tau * r_star / (1 + tau * kappa))
    alpha = 1 / (1 + tau * kappa)
    
    r0 = kappa * np.log(K*x**(alpha)/y**(alpha)) + r_star
    
    k1 = K**(-1/(tau*kappa)) * np.exp(-r0/kappa)
    
    c1 = y * (np.exp(1/kappa * (r0 - r_star)) + 1)**(tau*kappa + 1)
    c2 = c1**(1/(1 + tau*kappa))

#     dx_du = -c2*(1 + tau*kappa)*k1*(1/(tau*kappa)) \
#             * (K + k1*u**(1/(tau*kappa)))**(-2-tau*kappa) \
#             * u**(1/(tau*kappa)-1)

    density = c2*(1+tau*kappa)/(tau*kappa)*K**(-1/(tau*kappa))*np.exp(-r0/kappa+r0*tau) \
                * (K + K**(-1/(tau*kappa))*np.exp(-r0/kappa)*u**(1/(tau*kappa)))**(-2-tau*kappa) \
                * u**(1/(tau*kappa)-1)
    
    return density

# %%
kappa = 0.15
r_star = 0.05

# %%
price = np.linspace(0.01, 2, 1000)

# %%
x0=1
y0=1 

tau = 0.99 

lob = []

ts = [0.1, 0.5, 0.99, 5, 10]

for tau in ts: 

    lob.append(pd.DataFrame(
        {
            'density': pd.Series(lob_density(x0, y0, tau, kappa, r_star, price)),
            'price': pd.Series(price), 
            'tau': str(tau), 
            'x': x0, 
            'y': y0, 
        }
    )
    )
    
lob = pd.concat(lob)

# %%
fig, ax = plt.subplots(figsize=(10, 4))

a = sns.lineplot(data=lob, x='price', y='density', hue='tau', palette='tab10')

# for tau, color in zip(ts, sns.color_palette('tab10')): 
#     plt.axvline(np.exp(-r_star * tau), ymin=0, ymax=0.9, color=color, 
#                 linewidth=1, linestyle='dashed')

# %% [markdown]
# $$
# P_0 = e^{-r0*\tau}
# $$

# %%
import json


def read_data(folder_dir, file_path):
    file_path = os.path.join(folder_dir, file_path)

    with open(file_path, 'r') as file:
        data = json.load(file)

    _df = pd.DataFrame(data['value'])
    _df['timestamp'] = data['timestamp']
    _df['pool_address'] = data['pool_address']

    return _df

# %%
df = read_data('data/tracking/notional-v3/', 'ALL_INFORMATION.json')

# %%
df.query('abs(interest_rate) < 2').interest_rate.plot()
# Out:
# <Axes: >
