# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns 
import numpy as np

# %%
import yaml

# %%
import os 

os.chdir('E://bond-dex/bond-amm-simulation/')

# %%
from simulation.__NaiveTradeSimulator import NaiveTradeSimulator

# %%
from scripts.generate_stats_v1 import plot_stats

# %%
# %load_ext autoreload

# %% [markdown]
# ## Trade behaviour

# %%
trade_df = pd.read_csv('sources/input/actor_trade/single_trade.csv')

# %%
trade_df.head()
# Out:
#    timestamp  action  cash_volume
# 0          1  borrow     0.002636
# 1          2  borrow     0.004011
# 2          3  borrow     0.002832
# 3          4  borrow     0.000882
# 4          5    lend     0.000994

# %%
trade_df.cash_volume /= 4

# %%
LENGTH = 24 * 60

# %%
trade_df['day'] = (trade_df.timestamp / LENGTH).astype('int') * LENGTH
trade_df['net_volume'] = trade_df.apply(lambda row: row['cash_volume'] if row['action'] == 'lend'
                                                       else -row['cash_volume'], axis=1)

# %%
trade_df = trade_df[trade_df.day < 180 * LENGTH]

# %%
agg_trade = trade_df.groupby(['day', 'action'], as_index=False).agg({'net_volume': 'sum'})

# %%
net_trade = agg_trade.groupby('day', as_index=False).agg({'net_volume': 'sum'})

# %%
agg_trade['cum_volume'] = agg_trade.groupby('action')['net_volume'].transform(lambda x: np.cumsum(x))

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 6))

sns.lineplot(data=agg_trade, x='day', y='net_volume', hue='action', 
             ax=axs[0])

sns.lineplot(data=net_trade, x='day', y='net_volume', 
             ax=axs[0])

axs[0].grid(True)

sns.lineplot(data=agg_trade, x='day', y='cum_volume', hue='action', 
             ax=axs[1])
axs[1].grid(True)

plt.show()

# %% [markdown]
# ## Proposed logit

# %% [markdown]
# $p = \frac{X_0}{X_0 + y_0}$
#
# $r = \kappa logit(p) + r^{\star}$

# %% [markdown]
# $\alpha = \frac{1}{1 + \tau\kappa}$
#
# $B^\star = e^{-r^\star \tau}$
#
# $X_0 = x_0B^\star$
#
# $X_{1}^{\alpha} + y_{1}^{\alpha} = X_{0}^{\alpha} + y_{0}^{\alpha}$
#
# $x_1 = X_{1}B^\star$

# %%
_user_defined_func_path = "scripts/price_functions/price_v1.py"

# %%
# %%writefile {_user_defined_func_path}
#
# import numpy as np
# from scipy.special import logit
#
#
# def calculate_price(x, y, dx, dy, time_to_maturity, maturity_length, r_star, kappa) -> float:
#     tau = time_to_maturity
#
#     alpha = 1 / (1 + tau * kappa)
#     Br = np.exp(-r_star * tau)
#
#     C = (x * Br) ** alpha + y ** alpha
#
#     if dx != 0:
#         new_x = x + dx
#         new_y = (C - (Br * new_x) ** alpha) ** (1 / alpha)
#         dy = new_y - y
#     elif dy != 0:
#         new_y = y + dy
#         new_x = (C - new_y ** alpha) ** (1 / alpha) / Br
#         dx = new_x - x
#
#     if abs((x * Br) ** alpha + y ** alpha - ((x + dx) * Br) ** alpha - (y + dy) ** alpha) > 0.00001:
#         raise Exception('Something wrong with ODE!')
#
#     r0 = r_star * alpha + kappa * alpha * np.log(x / y)
#     if abs(logit(x * np.exp(-r0 * tau) / (x * np.exp(-r0 * tau) + y)) * kappa + r_star - r0) > 0.00001:
#         raise Exception('R0 not match!')
#
#     if dx == 0 and dy == 0:
#         dy = -np.exp(-tau * r0)
#         dx = 1
#
#     price = abs(dy / dx)
#
#     return price
# Out:
# Overwriting scripts/price_functions/price_v1.py

# %%
# %%writefile config/user_defined_v1.yml
#
#
# version_name: 'v1'
#
# config:
#   simulation:
#     simulation_length: 525500
#     begin_trade_time: 0
#     maturity: 525600
#     initial_cash: 0.5
#     initial_bond: 0.5256355481880121
#     bond_burning: 1
#
#   fee:
#     rate: .000
#
#   pricing_config:
#       pricing_method: 'user-defined'
#       params:
#         price_function: 'scripts/price_functions/price_v1.py'
#         kappa: 0.1
#         r_star: 0.05
#
#   other-protocol:
#     type: 'CIR'
#     params:
#         a: 5
#         b: 0.05
#         sigma: 0.1
#         r0: 0.04
#
#   arbitrageur:
#     strategy: 'naive-arbitrageur'
#     params:
#       estimate_func: 'polybond'
#       kappa: 0.1
#       r_star: 0.05
#
# #   trader:
# #     trade_data: 'sources/input/actor_trade/single_trade2.csv'
#
#   tracking:
#     dir: 'data/tracking/v1.1'
# Out:
# Overwriting config/user_defined_v1.yml

# %%
# %autoreload 2

from simulation.__NaiveTradeSimulator import NaiveTradeSimulator

# %%
with open('config/user_defined_v1.yml') as file:
    metadata = yaml.safe_load(file)

simulator = NaiveTradeSimulator(metadata['config'])
simulator.run()
# Out:
# Initialized simulation!
#
# ------------- Begin running simulation -------------
# 100%|███████████████████████████████████████████████████████████████████████| 525500/525500 [00:50<00:00, 10319.25it/s]
# Total_burn: -0.04221962355974479
#
# Saving tracking data to data/tracking/v1.1
#
# ------------------ Done simulation ------------------

# %%
# %autoreload 2

from scripts.generate_stats_v1 import plot_stats

# %%
fig = plt.figure(figsize=(10, 16))

plot_stats('data/tracking/v1.1', 'ALL_INFORMATION.json', fig_size=(18, 9))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# %autoreload 2

from scripts.generate_stats_v2 import plot_stats

fig = plt.figure(figsize=(10, 16))

plot_stats('data/tracking/v1.1', 'ALL_INFORMATION.json', fig_size=(18, 9))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Notional Finance

# %%
# %%writefile config/logit_notional_v1.yml
#
# version_name: 'linear-notional-v1'
#
# # time unit: minute
#
# config:
#   simulation:
#     simulation_length: 525500
#     begin_trade_time: 0
#     maturity: 525600
#     initial_cash: 0.5
#     initial_bond: 0.5256355481880121
#
#   fee:
#     rate: 0.
#
#   pricing_config:
#       pricing_method: 'logit-notional'
#       params:
#         scalar: 10
#         anchor: 1.05
#
#   other-protocol:
#     type: 'CIR'
#     params:
#         a: 5
#         b: 0.05
#         sigma: 0.1
#         r0: 0.04
#
#   arbitrageur:
#     strategy: 'naive-arbitrageur'
#     params:
#       estimate_func: 'notional'
#       kappa: 0.1
#       r_star: 0.05
#
#   trader:
#     trade_data: 'sources/input/actor_trade/single_trade2.csv'
#
#   tracking:
#     dir: 'data/tracking/logit_notional'
# Out:
# Overwriting config/logit_notional_v1.yml

# %%
# %autoreload 2

from simulation.__NaiveTradeSimulator import NaiveTradeSimulator

# %%
with open('config/logit_notional_v1.yml') as file:
    metadata = yaml.safe_load(file)

simulator = NaiveTradeSimulator(metadata['config'])
simulator.run()
# Out:
# Initialized simulation!
#
# ------------- Begin running simulation -------------
# 100%|████████████████████████████████████████████████████████████████████████| 525500/525500 [01:38<00:00, 5335.41it/s]
# Total_burn: 0
#
# Saving tracking data to data/tracking/logit_notional
#
# ------------------ Done simulation ------------------

# %%
fig = plt.figure(figsize=(10, 8))

plot_stats('data/tracking/logit_notional/', 'ALL_INFORMATION.json', fig_size=(12, 9))
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
def lob_density(x, y, tau, kappa, r_star, u):
    
    K = np.exp(-tau * r_star / (1 + tau * kappa))
    alpha = 1 / (1 + tau * kappa)
    
    r0 = kappa * np.log(K*x**(alpha)/y**(alpha)) + r_star
    
    k1 = K**(-1/(tau*kappa)) * np.exp(-r0/kappa)
    
    c1 = y * (np.exp(1/kappa * (r0 - r_star)) + 1)**(tau*kappa + 1)
    c2 = c1**(1/(1 + tau*kappa))

#     dx_du = -c2*(1 + tau*kappa)*k1*(1/(tau*kappa)) \
#             * (K + k1*u**(1/(tau*kappa)))**(-2-tau*kappa) \
#             * u**(1/(tau*kappa)-1)

    density = c2*(1+tau*kappa)/(tau*kappa)*K**(-1/(tau*kappa))*np.exp(-r0/kappa+r0*tau) \
                * (K + K**(-1/(tau*kappa))*np.exp(-r0/kappa)*u**(1/(tau*kappa)))**(-2-tau*kappa) \
                * u**(1/(tau*kappa)-1)
    
    return density

# %%
kappa = 0.15
r_star = 0.05

# %%
price = np.linspace(0.01, 2, 1000)

# %%
x0=1
y0=1 

tau = 0.99 

lob = []

ts = [0.1, 0.5, 0.99, 5, 10]

for tau in ts: 

    lob.append(pd.DataFrame(
        {
            'density': pd.Series(lob_density(x0, y0, tau, kappa, r_star, price)),
            'price': pd.Series(price), 
            'tau': str(tau), 
            'x': x0, 
            'y': y0, 
        }
    )
    )
    
lob = pd.concat(lob)

# %%
fig, ax = plt.subplots(figsize=(10, 4))

a = sns.lineplot(data=lob, x='price', y='density', hue='tau', palette='tab10')

# for tau, color in zip(ts, sns.color_palette('tab10')): 
#     plt.axvline(np.exp(-r_star * tau), ymin=0, ymax=0.9, color=color, 
#                 linewidth=1, linestyle='dashed')

# %% [markdown]
# $$
# P_0 = e^{-r0*\tau}
# $$

# %%
import json


def read_data(folder_dir, file_path):
    file_path = os.path.join(folder_dir, file_path)

    with open(file_path, 'r') as file:
        data = json.load(file)

    _df = pd.DataFrame(data['value'])
    _df['timestamp'] = data['timestamp']
    _df['pool_address'] = data['pool_address']

    return _df

# %%
df = read_data('data/tracking/v1.1/', 'ALL_INFORMATION.json')

# %%
(df.cash + df.net_bond*np.exp(-df.interest_rate*(365*24*60 - df.timestamp)/(365*24*60))).plot()
# Out:
# <Axes: >

# %%
from scripts.generate_stats_v1 import _make_stats

# %%
df = _make_stats(df, 0.5)

# %%
df.arbitrageur_cash.plot()
# Out:
# <Axes: >

# %%
(df.cash + df.net_bond * np.exp(-df.interest_rate * df.time_to_maturity / (365*24*60))).plot()
# Out:
# <Axes: >

# %%
df
# Out:
#          cash      bond  net_bond  time_to_maturity  interest_rate  \
# 0    0.500000  0.525636 -0.000000            525599       0.050000
# 1    0.515000  0.509905 -0.015726            525499       0.044551
# 2    0.515000  0.509901 -0.015726            525399       0.044551
# 3    0.515000  0.509896 -0.015726            525299       0.044551
# 4    0.515000  0.509892 -0.015726            525199       0.044551
# ..        ...       ...       ...               ...            ...
# 995  0.438284  0.587318  0.064513            426099       0.073326
# 996  0.438284  0.587310  0.064513            425999       0.073326
# 997  0.438284  0.587302  0.064513            425899       0.073326
# 998  0.438284  0.587294  0.064513            425799       0.073326
# 999  0.438284  0.587285  0.064513            425699       0.073326
#
#      accumulated_fee  ref_price  ref_interest_rate  arbitrageur_cash  \
# 0                  0        NaN           0.040000         10.000000
# 1                  0        NaN           0.040834         10.009022
# 2                  0        NaN           0.041973         10.009022
# 3                  0        NaN           0.041164         10.009022
# 4                  0        NaN           0.038459         10.009022
# ..               ...        ...                ...               ...
# 995                0        NaN           0.080213          9.946705
# 996                0        NaN           0.080439          9.946705
# 997                0        NaN           0.082460          9.946705
# 998                0        NaN           0.081012          9.946705
# 999                0        NaN           0.079694          9.946705
#
#      timestamp                                pool_address  pv_net_bond  \
# 0            1  0xzbqxbwxhdlvdpuasfzwxtjmxswpius1698770155    -0.000000
# 1          101  0xzbqxbwxhdlvdpuasfzwxtjmxswpius1698770155    -0.015041
# 2          201  0xzbqxbwxhdlvdpuasfzwxtjmxswpius1698770155    -0.015041
# 3          301  0xzbqxbwxhdlvdpuasfzwxtjmxswpius1698770155    -0.015041
# 4          401  0xzbqxbwxhdlvdpuasfzwxtjmxswpius1698770155    -0.015041
# ..         ...                                         ...          ...
# 995      99501  0xzbqxbwxhdlvdpuasfzwxtjmxswpius1698770155     0.060790
# 996      99601  0xzbqxbwxhdlvdpuasfzwxtjmxswpius1698770155     0.060790
# 997      99701  0xzbqxbwxhdlvdpuasfzwxtjmxswpius1698770155     0.060791
# 998      99801  0xzbqxbwxhdlvdpuasfzwxtjmxswpius1698770155     0.060792
# 999      99901  0xzbqxbwxhdlvdpuasfzwxtjmxswpius1698770155     0.060793
#
#       pv_bond  pool_value  net_pool_value  future_pool_value       PnL  \
# 0    0.500000    1.000000        0.500000           0.500000  0.000000
# 1    0.487691    1.002691        0.499959           0.499274 -0.000041
# 2    0.487691    1.002691        0.499959           0.499274 -0.000041
# 3    0.487691    1.002691        0.499959           0.499274 -0.000041
# 4    0.487691    1.002691        0.499959           0.499274 -0.000041
# ..        ...         ...             ...                ...       ...
# 995  0.553423    0.991707        0.499073           0.502797 -0.000927
# 996  0.553423    0.991707        0.499074           0.502797 -0.000926
# 997  0.553423    0.991707        0.499075           0.502797 -0.000925
# 998  0.553423    0.991707        0.499076           0.502797 -0.000924
# 999  0.553423    0.991707        0.499077           0.502797 -0.000923
#
#      value_inventory_ratio  quantity_inventory_ratio
# 0                 0.512497                  0.500000
# 1                 0.497514                  0.486382
# 2                 0.497512                  0.486382
# 3                 0.497510                  0.486382
# 4                 0.497508                  0.486382
# ..                     ...                       ...
# 995               0.572657                  0.558051
# 996               0.572654                  0.558051
# 997               0.572650                  0.558051
# 998               0.572647                  0.558051
# 999               0.572643                  0.558051
#
# [1000 rows x 19 columns]
